# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# <img alt="" class="v jk jl" src="https://miro.medium.com/max/3544/1*ftnM93QhlS0A7I55QegbrA.jpeg" width="800" height="200">
#
#
#
#
# <h4> - Global used vehicle market is projected to grow at 5.3% CAGR. The key driving factors for the growth of this market are internet penetration enabling the availability of information of the used car, rise in demand for off-lease vehicle by the franchise, car dealers, and leasing offices, stringent vehicular emissions regulations, and the growing demand for car subscription services.</h4> <br>
#
# * - Geographically, the global used vehicle market has been segmented into the four regions of **North America, Europe, Asia-Pacific, and the Rest of the World**. Asia-Pacific is expected to hold the largest market share during the forecast period owing to the growing automotive industry in China, India, and Japan.
#
# * - North America is expected to grow at a significant rate during the forecast period due to the growing demand for passenger vehicle in the **US and Canada**.
#
# * - Due to the increased price of new cars, used car sales are on a global increase (Pal, Arora and Palakurthy, 2018).

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - This section is emphasised on providing some generic introduction to the problem that most companies confronts.
#
# - **Example Problem Statement:**
#
#   - In the past few years, prices of new cars have skyrocketed, due to which most people are incapable of buying a new one.
#
#   - Customers buying a new car always looks for assurity of their money to be worthy.
#
#   - But due to the increased price of new cars, used car sales are on a global increase (Pal, Arora and Palakurthy, 2018).
#
#   - There is a need for a used car price prediction system to effectively determine the worthiness of the car using a variety of features.
#
#   - Even though there are websites that offers this service, their prediction method may not be the best.
#
#   - Besides, different models and systems may contribute on predicting power for a used car’s actual market value.
#
#   - It is important to know their actual market value while both buying and selling.
#
# <p align="center"><img src="https://visme.co/blog/wp-content/uploads/2020/06/animated-interactive-infographics-header-wide.gif"></p>
#
# - Derive a scenario related to the problem statement and heads on to the journey of exploration.
#
# - **Example Scenario:**
#   - Cars Absolute, an American company buys and sells second hand cars.
#
#   - The company has earned its name because of sincerity in work and quality of services.
#
#   - But for past few months their sales is down for some reason and they are unable to figure it out.
#
#   - To tackle this problem they hired a genius team of data scientists. Consider you are one of them...

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
#!pip install -q datascience                                         # Package that is required by pandas profiling
#!pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# To install more libraries insert your code here..

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
#!pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import profile_report                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01| car           | Car brand name|
# |02| model         | Available car different Variants|
# |03| year          | purchasing Year|
# |04| body          | Body type-Hatchback, Sedan, Crossover etc|
# |05| mileage       | car Mileage|
# |06| engV          | Engine version|
# |07| engType       | Car Fuel type - Petrol, Diesel, gas etc|
# |08| drive         | Wheel Drive Front, back|
# |09| registration  | Check if the vechile is registered|
# |10| price         | Price of Car in $|

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (9576, 10)
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
data.describe(include='all')
# Out:
#                car          price   body      mileage         engV engType  \
# count         9576    9576.000000   9576  9576.000000  9142.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.646344     NaN
# std            NaN   24106.523436    NaN    98.629754     5.927699     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
profile = data.profile_report(title='CarDataset_Profilings',progress_bar=False, minimal=False)

# %%
#profile.to_file('CarDataset_Profilings.html')

# %% [markdown]
# ### Dataset Info:
# Number of Variables  - 10<br>
# Number of Records - 9567<br>
# Number of Missing Values - 945(1%)<br>
#
# ### Variable types
# 1) Categorical-5 <br>
# 2) Numeric - 3 <br>
# 3) Boolean - 1 <br>
#
#
#
# - **Body** has data divided into **6** distinct categories, sedan has highest values.
#
# - **Drive** has data divided into **3** distinct categories and has missing values of 5.3%.
#
# - **Registration** has data divided into **2** distinct categories. Yes being highest at 9015
#
# - **Model** has a **high cardinality (888 distinct values)**.
#
# - **EngV** has a Missing Values of 434 which is 4.6%
#
# - **Year** has a **starting range from 1953 to 2016**.<br>
#     2008 and 2007 has seen highest number of car sales
# - **Mileage** has starting range from 0 to 999<br>
#     Mileage has **442 Zeros** values (4.6%)<br>
#     It is **-ve** coorelated to **Car Price**
# - **Price** has starting range from 0(Zeros) to 5Lakhs<br>
#     It is **-ve** coorelated to **Mileage**
# - **Cars** has a **high cardinality (87 distinct values)**.

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %% [markdown]
# <h6> Converting the Column Names to lower Case and displaying the Null Values in each field

# %%
data.columns = data.columns.str.lower() #converting columns names to lower type
print(data.isnull().sum()) # Printing the count of Null Values against values
sns.heatmap(data.isnull()); ## Visual Representation on getting the columns with Null Values
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engv            434
# engtype           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %% [markdown]
# ## 1- Missing Value Handling

# %% [markdown]
# Handling Null Values -
#
# <b> 1 - Eng V </b>

# %%
newdf = data.copy()
engv_df_N = data[pd.isnull(data.engv)]# --- NaN Dataframe
engv_df_NN = data[~pd.isnull(data.engv)]# --- NotNull Dataframe
#print(engv_df_N.describe(include='all')) # --  Finding the describe method
#print(engv_df_NN.describe(include='all'))
#print(engv_df_N[engv_df_N['car']=='Nissan'].groupby(by=['model','body','engtype','drive'])['car'].count()) # Checking on Nissan Values
#engv_df_NN[engv_df_NN['car']=='Nissan'].groupby(by=['model','body','engtype'])['car'].count()
engv_df_N['engtype'].value_counts()
# Out:
# Other     188
# Petrol    128
# Gas        59
# Diesel     59
# Name: engtype, dtype: int64

# %%
#Replacing the Null Values of drive with median
newdf['engv'].fillna(newdf['engv'].median(),inplace=True, axis=0)
newdf.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engv              0
# engtype           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %% [markdown]
# <b> 2 - Drive </b>

# %%
#Replacing the Null Values of drive with Mode of the same
newdf['drive'].fillna(newdf['drive'].mode()[0],inplace=True) # Mode is "Full"
newdf.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engv            0
# engtype         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %% [markdown]
# ## 2 - Handling Inconsistent, Duplicates and Outliers

# %%
newdf.describe(include='all')
# Out:
#                car          price   body      mileage         engv engtype  \
# count         9576    9576.000000   9576  9576.000000  9576.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.617051     NaN
# std            NaN   24106.523436    NaN    98.629754     5.793361     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %% [markdown]
# <h6> 1 -  Dropping Duplicates Values </h6>

# %%
 #Dropping Duplicates
newdf.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# **2- Price** <br>
# It has Zero Values which is very strange and will not help in any of the analysis. So we need to relook on the same

# %%
pricezerodf = newdf[newdf['price'] == 0] # - To check count of Zero Price Value
print(pricezerodf.shape)
pricezerodf.describe(include='all')
# Out:
# (240, 10)
#                   car  price       body     mileage        engv engtype  \
# count             240  240.0        240  240.000000  240.000000     240
# unique             34    NaN          6         NaN         NaN       4
# top     Mercedes-Benz    NaN  crossover         NaN         NaN  Diesel
# freq               54    NaN         78         NaN         NaN     129
# mean              NaN    0.0        NaN   98.395833    3.167583     NaN
# std               NaN    0.0        NaN  100.624772    6.384613     NaN
# min               NaN    0.0        NaN    0.000000    0.800000     NaN
# 25%               NaN    0.0        NaN    8.750000    2.000000     NaN
# 50%               NaN    0.0        NaN   65.000000    2.500000     NaN
# 75%               NaN    0.0        NaN  161.250000    3.000000     NaN
# max               NaN    0.0        NaN  450.000000   99.990000     NaN
#
#        registration         year  model drive
# ...

# %% [markdown]
# **3-Mileage** <br>
# It has Zero Values which is very strange and will not help in any of the analysis. So we need to relook on the same

# %%
## Dropping the zero price as it is spread across all the models and we cannot predict the price for the same
newdf.drop(labels=newdf[newdf['price'] == 0].index,inplace=True)

# %%
# 2 - Zero Values in Mileage
mileagezerodf = newdf[newdf['mileage'] == 0]
print(mileagezerodf.shape)
# Out:
# (283, 10)

# %%
## Dropping the zero mileage as it is spread across all the models
newdf.drop(labels=newdf[newdf['mileage'] == 0].index,inplace=True)

# %%
 #Dropping Duplicates
newdf.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# <h6>4 - Year </h6> is in different format needs to be changed to Date Format

# %%
#Changing the Year to Datetype
newdf['year'] = pd.to_datetime(newdf['year'], format='%Y')

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
newdf.describe(include='all')
# Out:
#                car          price   body      mileage         engv engtype  \
# count         8940    8940.000000   8940  8940.000000  8940.000000    8940
# unique          86            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           874            NaN   3504          NaN          NaN    4129
# first          NaN            NaN    NaN          NaN          NaN     NaN
# last           NaN            NaN    NaN          NaN          NaN     NaN
# mean           NaN   14261.631394    NaN   145.468904     2.594406     NaN
# std            NaN   18537.514261    NaN    96.411671     5.808026     NaN
# min            NaN     259.350000    NaN     1.000000     0.100000     NaN
# 25%            NaN    5200.000000    NaN    79.000000     1.600000     NaN
# 50%            NaN    9100.000000    NaN   132.000000     2.000000     NaN
# ...

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %% [markdown]
# <h3> 1  - What is the YOY Car Sales and Revenue Trend </h6>

# %%
newdf['year'].value_counts().sort_values(ascending=True)
# YoY Comparision of Used Cars
plt.figure(figsize=(10,5))
plt.title('YoY Comparision Sales - Used Cars')
newdf.groupby(by='year')['car'].count().plot(kind='line');

# %% [markdown]
# ### from 1990, sales of car started with more than 100 Numbers. Will Filter out Cars after 1996

# %%
newdf1 = newdf[newdf['year'] >= '1995-01-01']

# %%
# YoY Comparision of Used Cars
plt.figure(figsize=(10,5))
plt.title('YoY Comparision Sales - Used Cars')
newdf1.groupby(by='year')['car'].count().plot(kind='line');

# %% [markdown]
# ### From the above Line Chart it is clear that Sales started to increase from 2002 but start dropping from 2009 and a small spike in 2010/11 and again start dropping

# %%
# YoY Comparision of Used Cars
plt.figure(figsize=(10,5))
plt.title('YoY Comparision Revenue - Used Cars')
newdf1.groupby(by='year')['price'].sum().plot(kind='line');

# %%
# YoY Comparision of Used Cars
plt.figure(figsize=(10,5))
plt.title('YoY Comparision Average Price/Unit - Used Cars')
newdf1.groupby(by='year')['price'].mean().plot(kind='line');

# %% [markdown]
# <h3> 2 -  What is the contribution of the Top 15 Car Company by No of Unit Sold and if it contributes to 70% create and analyse the data on this set </h3>

# %%
newdf1['car'].value_counts()[:15].sum()/len(newdf)*100  #-- Top 15 Car Contributes ~ 70% of the overall Data
# Out:
# 68.99328859060402

# %%
x1 = newdf1['car'].value_counts()[:15]

# %% [markdown]
# #### New df with Top 15 Car Contributer

# %%
Cars = newdf1[newdf1['car'].isin(x1.index)]

# %%
Cars.shape
# Out:
# (6168, 10)

# %%
Cars.describe(include='all')
# Out:
#                car          price   body      mileage         engv engtype  \
# count         6168    6168.000000   6168  6168.000000  6168.000000    6168
# unique          15            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           807            NaN   2451          NaN          NaN    2614
# first          NaN            NaN    NaN          NaN          NaN     NaN
# last           NaN            NaN    NaN          NaN          NaN     NaN
# mean           NaN   14499.572284    NaN   149.956064     2.498891     NaN
# std            NaN   18165.845017    NaN    92.452786     5.016591     NaN
# min            NaN     499.000000    NaN     1.000000     0.110000     NaN
# 25%            NaN    5900.000000    NaN    85.000000     1.600000     NaN
# 50%            NaN    9600.000000    NaN   140.000000     2.000000     NaN
# ...

# %% [markdown]
# <h3> 3 - Who are the Top 3 Contributor with respect to  No of Units Sold for the new Dataset</h3>

# %%
#Distribution by Absolute Numbers
Cars['car'].value_counts().sort_values(ascending=False).plot(kind='bar',figsize=(8,4),  fontsize=13);

# %%
#Distribution by Normalised Numbers
(Cars['car'].value_counts()/len(Cars)).sort_values(ascending=False).plot(kind='bar',figsize=(10,5), fontsize=13);

# %% [markdown]
# <h3> 4 - What is YoY Trend for Car,Drive, Registration, EngType & Body </h3>

# %%
plt.figure(figsize=(40,100))

Cars.pivot_table(values='drive',index='year',columns='car',aggfunc={len}).plot();

# %%
Cars.pivot_table(values='car',index='year',columns='drive',aggfunc={len}).plot();

# %%
Cars.pivot_table(values='car',index='year',columns='engtype',aggfunc={len}).plot();

# %%
Cars.pivot_table(values='car',index='year',columns='registration',aggfunc={len}).plot();

# %%
plt.figure(figsize=(15,10))
Cars.pivot_table(values='car',index='year',columns='body',aggfunc={len}).plot();

# %% [markdown]
# <h3> 5 - Since the Sales Start to drop from 2014, what was the split of Registration,Drive & EngType before 2014 and After 2014 </h3>

# %% [markdown]
# **1 - Registration**

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=Cars, x='car', hue='registration', order=Cars['car'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='car', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=Cars[Cars['year']>='2014-01-01'], x='car',order=Cars['car'].value_counts().index,  hue='registration');

# %% [markdown]
# **2 - Drive**

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=Cars, x='car', hue='drive',order=Cars['car'].value_counts().index);

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=Cars[Cars['year']>='2014-01-01'], x='car', hue='drive',order=Cars['car'].value_counts().index);

# %% [markdown]
# **3 -  EngType**

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=Cars, x='engtype', hue='car',order=Cars['engtype'].value_counts().index);

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot(data=Cars[Cars['year']>='2014-01-01'], x='engtype', hue='car',order=Cars['engtype'].value_counts().index);

# %% [markdown]
# <h3> 6 - What was the YoY Sales of Car Company to check the Drop and Growth </h3>

# %%
pd.crosstab(Cars['car'],Cars['year'])
# Out:
# year           1995-01-01  1996-01-01  1997-01-01  1998-01-01  1999-01-01  \
# car
# Audi                    3          16          10          16          24
# BMW                    15          16          28          25          23
# Chevrolet               0           0           0           0           0
# Daewoo                  0           1           2          10           4
# Ford                    5           5           3           5           4
# Hyundai                 0           0           0           2           1
# Mercedes-Benz          12          14          20          18          27
# Mitsubishi              0           5           6           2           3
# Nissan                  4           3           3           4           5
# Opel                   11          16          20          18          11
# Renault                 0           1           3           3           4
# Skoda                   0           2           0           5           1
# ...

# %% [markdown]
# <i><h3>No Major Drop in Sales Unit for BMW in 2016 as it got to the Sales unit same  level as of 2013</h3></i><br>

# %%
Cars[(Cars['car']=='BMW') & (Cars['year']>='2014-01-01') ].describe(include='all')
# Out:
#         car          price       body    mileage       engv engtype  \
# count    64      64.000000         64  64.000000  64.000000      64
# unique    1            NaN          5        NaN        NaN       3
# top     BMW            NaN  crossover        NaN        NaN  Diesel
# freq     64            NaN         37        NaN        NaN      37
# first   NaN            NaN        NaN        NaN        NaN     NaN
# last    NaN            NaN        NaN        NaN        NaN     NaN
# mean    NaN   65934.937500        NaN  18.609375   2.614844     NaN
# std     NaN   25008.857682        NaN  20.836184   0.903770     NaN
# min     NaN   31000.000000        NaN   1.000000   0.650000     NaN
# 25%     NaN   45875.000000        NaN   1.750000   2.000000     NaN
# 50%     NaN   64000.000000        NaN  10.000000   2.000000     NaN
# 75%     NaN   76041.250000        NaN  30.000000   3.000000     NaN
# max     NaN  137000.000000        NaN  74.000000   5.000000     NaN
#
# ...

# %%
def CarCat(cat):
    if cat == 'BMW':
        return 'BMW'
    elif cat == 'Volkswagen':
        return 'Volkswagen'
    elif cat == 'Mercedes-Benz':
        return 'Merc'
    else:
        return 'Others'

# %%
Cars['CarT'] = Cars['car'].map(CarCat)

# %%
Cars['CarT'].value_counts()
# Out:
# Others        4030
# Volkswagen     807
# Merc           734
# BMW            597
# Name: CarT, dtype: int64

# %%
pd.crosstab([Cars['drive'],Cars['CarT']],Cars['year'])
# Out:
# year              1995-01-01  1996-01-01  1997-01-01  1998-01-01  1999-01-01  \
# drive CarT
# front BMW                  1           1           2           0           2
#       Merc                 0           2           3           5          13
#       Others              16          47          34          54          54
#       Volkswagen          12          13           9          14          21
# full  BMW                  0           0           0           0           0
#       Merc                 0           0           2           2           1
#       Others               5           4           7           6           7
#       Volkswagen           0           0           0           0           0
# rear  BMW                 14          15          26          25          21
#       Merc                12          12          15          11          13
#       Others              10           9          10           9           6
# ...

# %%
pd.crosstab([Cars['body'],Cars['CarT']],Cars['year'])
# Out:
# year                  1995-01-01  1996-01-01  1997-01-01  1998-01-01  \
# body      CarT
# crossover BMW                  0           0           0           0
#           Merc                 0           0           1           2
#           Others               4           3           3           3
#           Volkswagen           0           0           0           0
# hatch     BMW                  0           0           0           0
#           Merc                 0           0           0           0
#           Others               6           7           8           7
#           Volkswagen           1           4           1           4
# other     BMW                  1           0           2           4
#           Merc                 1           2           1           3
#           Others               0           3           1           4
#           Volkswagen           1           0           3           1
# ...

# %% [markdown]
# <h6> 7 -  What is the Top3 Car and Remaining Car(Others) split % with respect to Body of the Car </h6>

# %%
f,ax = plt.subplots(2,2,figsize=(12,10))
Cars['body'][Cars['CarT']=='BMW'].value_counts().plot(kind='pie',ax=ax[0][0],autopct='%1.1f%%')
Cars['body'][Cars['CarT']=='Volkswagen'].value_counts().plot(kind='pie',ax=ax[0][1],autopct='%1.1f%%')
Cars['body'][Cars['CarT']=='Merc'].value_counts().plot(kind='pie',ax=ax[1][0],autopct='%1.1f%%')
Cars['body'][Cars['CarT']=='Others'].value_counts().plot(kind='pie',ax=ax[1][1],autopct='%1.1f%%')
ax[0][0].set_title('BMW')
ax[0][1].set_title('Volkwagen')
ax[1][0].set_title('Merc')
ax[1][1].set_title('Others')
# Out:
# Text(0.5, 1.0, 'Others')

# %% [markdown]
# <h6> 8 -  What is the YoY Distribution of Body of the Car </h6>

# %%
f,ax = plt.subplots(2,2,figsize=(12,10))
Cars['body'][Cars['year']=='2000-01-01'].value_counts().plot(kind='pie',ax=ax[0][0],autopct='%1.1f%%')
Cars['body'][Cars['year']=='2008-01-01'].value_counts().plot(kind='pie',ax=ax[0][1],autopct='%1.1f%%')
Cars['body'][Cars['year']=='2014-01-01'].value_counts().plot(kind='pie',ax=ax[1][0],autopct='%1.1f%%')
Cars['body'][Cars['year']=='2016-01-01'].value_counts().plot(kind='pie',ax=ax[1][1],autopct='%1.1f%%')
ax[0][0].set_title('2000')
ax[0][1].set_title('2008')
ax[1][0].set_title('2014')
ax[1][1].set_title('2016')
# Out:
# Text(0.5, 1.0, '2016')

# %% [markdown]
# <h6> 9 -  What is the YoY Distribution of Drive of the Car </h6>

# %%
f,ax = plt.subplots(2,2,figsize=(12,10))
Cars['drive'][Cars['year']=='2000-01-01'].value_counts().plot(kind='pie',ax=ax[0][0],autopct='%1.1f%%')
Cars['drive'][Cars['year']=='2008-01-01'].value_counts().plot(kind='pie',ax=ax[0][1],autopct='%1.1f%%')
Cars['drive'][Cars['year']=='2014-01-01'].value_counts().plot(kind='pie',ax=ax[1][0],autopct='%1.1f%%')
Cars['drive'][Cars['year']=='2016-01-01'].value_counts().plot(kind='pie',ax=ax[1][1],autopct='%1.1f%%')
ax[0][0].set_title('2000')
ax[0][1].set_title('2008')
ax[1][0].set_title('2014')
ax[1][1].set_title('2016')
# Out:
# Text(0.5, 1.0, '2016')

# %%
f,ax = plt.subplots(2,2,figsize=(12,10))
Cars['engtype'][Cars['year']=='2000-01-01'].value_counts().plot(kind='pie',ax=ax[0][0],autopct='%1.1f%%')
Cars['engtype'][Cars['year']=='2008-01-01'].value_counts().plot(kind='pie',ax=ax[0][1],autopct='%1.1f%%')
Cars['engtype'][Cars['year']=='2014-01-01'].value_counts().plot(kind='pie',ax=ax[1][0],autopct='%1.1f%%')
Cars['engtype'][Cars['year']=='2016-01-01'].value_counts().plot(kind='pie',ax=ax[1][1],autopct='%1.1f%%')
ax[0][0].set_title('2000')
ax[0][1].set_title('2008')
ax[1][0].set_title('2014')
ax[1][1].set_title('2016')
# Out:
# Text(0.5, 1.0, '2016')

# %% [markdown]
# <h3> 10 - What is the YOY Sales of Combination - (Body, Drive) & (Body, EngType),(Body, Drive) </h3>

# %%
pd.crosstab([Cars['body'],Cars['drive']],Cars['year'])
# Out:
# year             1995-01-01  1996-01-01  1997-01-01  1998-01-01  1999-01-01  \
# body      drive
# crossover front           0           0           0           1           0
#           full            4           3           4           4           6
#           rear            0           0           0           0           0
# hatch     front           7          11           9          11          13
#           full            0           0           0           0           0
#           rear            0           0           0           0           0
# other     front           1           3           4           4          13
#           full            0           0           0           0           0
#           rear            2           2           3           8           4
# sedan     front          13          32          27          37          28
#           full            1           1           3           3           0
# ...

# %%
pd.crosstab([Cars['engtype'],Cars['body']],Cars['year'])
# Out:
# year               1995-01-01  1996-01-01  1997-01-01  1998-01-01  1999-01-01  \
# engtype body
# Diesel  crossover           0           2           2           2           2
#         hatch               0           0           0           1           5
#         other               2           1           3           4           5
#         sedan               3          11          11          16          21
#         vagon               1           8           5           8          14
#         van                 6           6           6           9          21
# Gas     crossover           1           1           1           2           2
#         hatch               3           5           6           4           1
#         other               0           1           1           3           4
#         sedan              15          14          26          27          14
#         vagon               4           5           4           2           1
# ...

# %% [markdown]
# <h3> 11 -  Under Which Mileage Cut Did Most of the Car Sold ? </h3>

# %%
Cars['MilegaeCut'] = pd.cut(Cars['mileage'],bins=[0,10,20,100,200,400,1500], labels=['<10','11-20','21-100','101-200','201-400','GTR400'])

# %%
pd.crosstab(Cars['MilegaeCut'],Cars['year'])
# Out:
# year        1995-01-01  1996-01-01  1997-01-01  1998-01-01  1999-01-01  \
# MilegaeCut
# <10                  6           4           2           3           4
# 11-20                0           1           0           3           1
# 21-100               4           4           4           3           7
# 101-200              7          16          16          16          30
# 201-400             47          72          81          96          90
# GTR400               6           6           5           5           6
#
# year        2000-01-01  2001-01-01  2002-01-01  2003-01-01  2004-01-01  ...  \
# MilegaeCut                                                              ...
# <10                  3           3           4           2           5  ...
# 11-20                1           0           0           0           0  ...
# 21-100               2           7           4          11          15  ...
# 101-200             51          48          60          79         112  ...
# ...

# %% [markdown]
# <h3> 12 What is the price Range where maximim no of Car Sales are happening and split on different Car Type</h3>

# %%
Cars['price'].describe()
# Out:
# count      6168.000000
# mean      14499.572284
# std       18165.845017
# min         499.000000
# 25%        5900.000000
# 50%        9600.000000
# 75%       16300.000000
# max      300000.000000
# Name: price, dtype: float64

# %%
Cars['PriceCut'] = pd.cut(Cars['price'], bins=[0,10000,20000,30000,40000,50000,300000], labels=['Less10K', '10k-20K','20K-30K','30K-40K','40K-50K', 'GTR50K'])

# %%
pd.crosstab([Cars['PriceCut'],Cars['CarT']],Cars['year'])
# Out:
# year                 1995-01-01  1996-01-01  1997-01-01  1998-01-01  \
# PriceCut CarT
# Less10K  BMW                 15          16          28          25
#          Merc                11          13          18          17
#          Others              31          59          51          69
#          Volkswagen          12          13           9          13
# 10k-20K  BMW                  0           0           0           0
#          Merc                 1           1           2           1
#          Others               0           1           0           0
#          Volkswagen           0           0           0           1
# 20K-30K  BMW                  0           0           0           0
#          Merc                 0           0           0           0
#          Others               0           0           0           0
#          Volkswagen           0           0           0           0
# 30K-40K  BMW                  0           0           0           0
# ...

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.countplot(data=Cars,x='car',hue='PriceCut')
# Out:
# <AxesSubplot:xlabel='car', ylabel='count'>

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# - In this part you need to provide a conclusion about your overall analysis.
#
# - Write down some short points that you have observed so far.

# %% [markdown]
# ## Conclusions
#
# - **Sales YOY** has been highest in 2008 with 1092 Units and drastically down in 129 in 2016
# - **Price per Unit Revenue** still shows upper trend with ~50K USD in 2016
#
# - **Volkswagen** has the highest share in the dataset with 13% followed by *Mercedes Benz* and *BMW*
# - **Of the 84 Unique Car available** Top 15 Car Contributes **70%** of overall share which makes more sense to analyse this dataset
# - All the Cars post 2014 are registered Cars expect few for Volkswagen
# -  None of the cars Sold by eng Type **GAS** in 2016
# - Engine Type "Petrol and Diesel" are most preffered
#
# - Most Sales are happening in the price range between 10000/ to 40000/-

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# - This is a very crucial part where you will present your actionable insights.
# - You need to give suggestions about what could be applied and what not.
# - Make sure that these suggestions are short and to the point, ultimately it's a catalyst to your business.

# %% [markdown]
# # Insights -
# - 1) Sales of **Body Type** of Car has changed Drastically from **Sedan(50%)** Leading in 2000 with shift to **Crossover(46%)** in 2016. Tremendous drop can be seen in Vagon, Hatch and Van
# - 2) Sales of **Drive Type** of Car also has seen a change in shift from Front Type(46%) in 2000 to Full Type (50%) in 2016
# - 3) **BMW** is the only car company which has shown stability in sales number **2013 - 25 ,2014 - 21,2015 - 15, 2016 -26** even when most of the car companys are down by more than 50% from their 2013 numbers
# - 3.1) **As per the trend above it is clear that shift of body type of car has moved to crossover**.BMW has almost sold 60% of car as Crossover from 2014 to 2016 with drive type = Full
#
# # Recommendation and Suggestions
#
# <h6><u> Introduce more Cars basis Trend and Customer Preference :</u></h6>
#
#
# -**Full Wheel Drive with Cross Over are most preferred**
#
# -**Avoid Gas Engine Type. Petrol and Diesel cars are still in demand**
#
# -**Introduce more luxury and premium cars from segment like BMW , Mercedez-Benz, etc**
